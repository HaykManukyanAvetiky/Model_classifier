3D0%26cbstore%3D1%26resultview%3DsortbyPopular%26lightbox%3D%26gname%3D%26gtype%3D%26apalic%3D%26tbar%3D1%26pc%3D%26simid%3D%26cap%3D1%26customgeoip%3D%26vd%3D0%26cid%3D%26pe%3D%26so%3D%26lb%3D%26pl%3D0%26plno%3D%26fi%3D0%26langcode%3Den%26upl%3D0%26cufr%3D%26cuto%3D%26howler%3D%26cvrem%3D0%26cvtype%3D0%26cvloc%3D0%26cl%3D0%26upfr%3D%26upto%3D%26primcat%3D%26seccat%3D%26cvcategory%3D*%26restriction%3D%26random%3D%26ispremium%3D1%26flip%3D0%26contributorqt%3D%26plgalleryno%3D%26plpublic%3D0%26viewaspublic%3D0%26isplcurate%3D0%26imageurl%3D%26saveQry%3D%26editorial%3D1%26t%3D0%26edoptin%3D'
          ]

# %%
imglist = []

# %%
for link in links:
  for j in range(1,100):
    url = link.format(j)
    try:
      r = requests.get(url  , headers=headers)
      soup = BeautifulSoup(r.content, 'html.parser')
      for i in soup.select('span > img '):
        try:
          imglist.append(i['data-src'] + '\n')  
          print(i['data-src'] + '\n')  
        except:
          pass    
    except:
      pass

# %%
link = 'https://www.shutterstock.com/ru/search/plus+size+models?image_type=photo&orientation=vertical&number_of_people=1&mreleased=true&age=20s&page={}'
for j in range(1,100):
  url = link.format(j)
  try:
    r = requests.get(url  , headers=headers)
    soup = BeautifulSoup(r.content, 'html.parser')
    for i in soup.select('a > img '):
      try:
        imglist.append(i['src'] + '\n')  
        print(i['src'] + '\n')  
      except:
        pass    
  except:
    pass

# %%
url = 'https://www.plus-sizemodels.com/'
models = []
try:
  r = requests.get(url  , headers=headers)
  soup = BeautifulSoup(r.content, 'html.parser')
  for i in soup.select('div > a '):
    try:
      models.append(i['href'] + '\n')  
      print(i['href'] + '\n')  
    except:
      pass    
except:
  pass
  
for url in models:
  try:
    r = requests.get(url  , headers=headers)
    soup = BeautifulSoup(r.content, 'html.parser')
    for i in soup.select('div > div > div > div > a > img '):
      try:
        imglist.append(i['href'] + '\n')  
        print(i['src'] + '\n')  
      except:
        pass    
  except:
    pass

# https://ru.depositphotos.com/stock-photos/модель-плюс-сайз.html?filter=all
# https://ru.depositphotos.com/stock-photos/модель-плюс-сайз.html?offset=20&sh=a7f34f40c97ff1e27dbaea3329c6ef39&filter=all

# %%
link = 'https://www.istockphoto.com/photos/plus-size-fashion?mediatype=photography&page={}&phrase=plus%20size%20fashion&sort=best'
for j in range(70):
  url = link.format(j)
  try:
    r = requests.get(url  , headers=headers)
    soup = BeautifulSoup(r.content, 'html.parser')
    for i in soup.select('gi-asset > article > a > figure > img'):
      try:
        imglist.append(i['src'] + '\n')  
        print(i['src'] + '\n')  
      except:
        pass    
  except:
    pass

# %%
link = 'https://www.gettyimages.com/photos/plus-size-model?mediatype=photography&page={}&phrase=plus%20size%20model&sort=best'
for j in range(70):
  url = link.format(j)
  try:
    r = requests.get(url  , headers=headers)
    soup = BeautifulSoup(r.content, 'html.parser')
    for i in soup.select('gi-asset > article > a > figure > img'): 
      try:
        imglist.append(i['src'] + '\n')  
        print(i['src'] + '\n')  
      except:
        pass    
  except:
    pass

# %%
with open(root_dir + '/plus_size.txt', 'w') as file:
  file.writelines(imglist)

# %%
len(imglist)
# Out:
# 15773

# %% [markdown]
# ## Fitness Model Fit Model

# %%
link = 'https://www.shutterstock.com/ru/search/female+fit?orientation=vertical&image_type=photo&mreleased=true&gender=female&category=Sports%2FRecreation&number_of_people=1&age=20s&page={}'

# %%
imglist = []

# %%
for j in range(1,1000):
  url = link.format(j)
  try:
    r = requests.get(url  , headers=headers)
    soup = BeautifulSoup(r.content, 'html.parser')
    for i in soup.select('a > img'):
      try:
        imglist.append(i['src'] + '\n')  
        print(i['src'] + '\n')  
      except:
        pass    
  except:
    pass

# %%
with open(root_dir + '/fitness.txt', 'w') as file:
  file.writelines(imglist)

# %%
len(imglist)
# Out:
# 19980

# %% [markdown]
# ## Swimsuit or Lingerie Model

# %%
links = ['https://www.shutterstock.com/ru/search/Lingerie+Model?image_type=photo&orientation=vertical&number_of_people=1&mreleased=true&age=20s&page={}',
         'https://www.shutterstock.com/ru/search/swimsuit+models?image_type=photo&orientation=vertical&number_of_people=1&mreleased=true&age=20s&page={}'
]

# %%
imglist = []

# %%
for link in links:
  for j in range(1,500):
    url = link.format(j)
    try:
      r = requests.get(url  , headers=headers)
      soup = BeautifulSoup(r.content, 'html.parser')
      for i in soup.select('a > img'):
        try:
          imglist.append(i['src'] + '\n')  
          print(i['src'] + '\n')  
        except:
          pass    
    except:
      pass

# %%
with open(root_dir + '/swimsuit.txt', 'w') as file:
  file.writelines(imglist)

# %%
len(imglist)
# Out:
# 19960

# %% [markdown]
# ##Commercial Or Catalog Model

# %%
imglist = []

# %%
links = ['https://www.shutterstock.com/ru/search/Commercial+Model?image_type=photo&orientation=vertical&mreleased=true&gender=female&page={}',
         'https://www.shutterstock.com/ru/search/Catwalk+Model?image_type=photo&orientation=vertical&mreleased=true&gender=female&age=20s&page={}',
         'https://www.shutterstock.com/ru/search/Mature+Model?image_type=photo&orientation=vertical&mreleased=true&gender=female&page={}',
         'https://www.shutterstock.com/ru/search/Catalog+Model?image_type=photo&orientation=vertical&mreleased=true&gender=female&page={}',
         'https://www.shutterstock.com/ru/search/Petite+model?image_type=photo&orientation=vertical&mreleased=true&gender=female&page={}',
         'https://www.shutterstock.com/ru/search/Industrial+Model?image_type=photo&orientation=vertical&mreleased=true&gender=female&page={}'

]

# %%
for link in links:
  for j in range(1,100):
    url = link.format(j)
    try:
      r = requests.get(url  , headers=headers)
      soup = BeautifulSoup(r.content, 'html.parser')
      for i in soup.select('a > img'):
        try:
          imglist.append(i['src'] + '\n')  
          print(i['src'] + '\n')  
        except:
          pass    
    except:
      pass

# %%
with open(root_dir + '/comercial.txt', 'w') as file:
  file.writelines(imglist)

# %%
len(imglist)
# Out:
# 9900

# %% [markdown]
# ## Fasion or Glamour models

# %%
links = ['https://www.shutterstock.com/ru/search/Glamour+Model?image_type=photo&orientation=vertical&mreleased=true&gender=female&age=20s&page={}',  
         'https://www.shutterstock.com/ru/search/Fashion+Model?image_type=photo&orientation=vertical&mreleased=true&gender=female&age=20s&page={}' 
        ]

# %%
imglist = []

# %%
for link in links:
  for j in range(1,500):
    url = link.format(j)
    try:
      r = requests.get(url  , headers=headers)
      soup = BeautifulSoup(r.content, 'html.parser')
      for i in soup.select('a > img'):
        try:
          imglist.append(i['src'] + '\n')  
          print(i['src'] + '\n')  
        except:
          pass    
    except:
      pass

# %%
with open(root_dir + '/fasion.txt', 'w') as file:
  file.writelines(imglist)

# %%
len(imglist)
# Out:
# 19960

# %% [markdown]
# ## Creating directories and download Images

# %%
# !mkdir -p test_data/1plus
# !mkdir -p test_data/2fit
# !mkdir -p test_data/3swimsuit

# !mkdir -p test_data/5commercial
# !mkdir -p test_data/6fasion


# !mkdir -p train_data/1plus
# !mkdir -p train_data/2fit
# !mkdir -p train_data/3swimsuit

# !mkdir -p train_data/5commercial
# !mkdir -p train_data/6fasion

# %%
import urllib.request
def download(info):
  train_data = 'train_data/'
  test_data = 'test_data/'
  with open( root_dir + info['file'] , 'r') as f:
    for name, url in enumerate(f.readlines()):
      if name <= 600 :
        path = test_data + info['dir']  + str(name) +'.jpg'
      else:
        path = train_data + info['dir']  + str(name) +'.jpg'
      try:
        urllib.request.urlretrieve(url,path) 
      except:
          pass
      #print(info['dir'] , '____' , name)

# %%
files = {
'plus': {'dir':'1plus/', 'file' : '/plus_size.txt'},
'fit' : {'dir':'2fit/', 'file':'/fitness.txt'},
'swimsuit': {'dir':'3swimsuit/', 'file':'/swimsuit.txt'},
'commercial': {'dir':'5commercial/','file':'/comercial.txt'},
'fasion': {'dir':'6fasion/', 'file':'/fasion.txt'}
}

# %%
from multiprocessing import Process
p1 = Process(target=download, args=(files['plus'],))
p2 = Process(target=download, args=(files['fit' ],))
p3 = Process(target=download, args=(files['swimsuit'],))
p4 = Process(target=download, args=(files['commercial'],))
p5 = Process(target=download, args=(files['fasion'],))
p1.start()
p2.start()
p3.start()
p4.start()
p5.start()
p1.join()
p2.join()
p3.join()
p4.join()
p5.join()
# Out:
# Streaming output truncated to the last 5000 lines.
# 2fit/ ____ 17861
# 6fasion/ ____ 17080
# 6fasion/ ____ 17081
# 6fasion/ ____ 17082
# 6fasion/ ____ 17083
# 6fasion/ ____ 17084
# 2fit/ ____ 17862
# 2fit/ ____ 17863
# 6fasion/ ____ 17085
# 2fit/ ____ 17864
# 2fit/ ____ 17865
# 6fasion/ ____ 17086
# 2fit/ ____ 17866
# 6fasion/ ____ 17087
# 6fasion/ ____ 17088
# 2fit/ ____ 17867
# 6fasion/ ____ 17089
# 6fasion/ ____ 17090
# 2fit/ ____ 17868
# 2fit/ ____ 17869
# 2fit/ ____ 17870
# 2fit/ ____ 17871
# 6fasion/ ____ 17091
# 2fit/ ____ 17872
# 6fasion/ ____ 17092
# 2fit/ ____ 17873
# 6fasion/ ____ 17093
# 6fasion/ ____ 17094
# 2fit/ ____ 17874
# 2fit/ ____ 17875
# 2fit/ ____ 17876
# 6fasion/ ____ 17095
# 2fit/ ____ 17877
# 6fasion/ ____ 17096
# 2fit/ ____ 17878
# 6fasion/ ____ 17097
# 6fasion/ ____ 17098
# 2fit/ ____ 17879
# 6fasion/ ____ 17099
# 2fit/ ____ 17880
# 2fit/ ____ 17881
# 6fasion/ ____ 17100
# 2fit/ ____ 17882
# 6fasion/ ____ 17101
# 2fit/ ____ 17883
# 6fasion/ ____ 17102
# ...

# %% [markdown]
# ## Resizing, zipping, saving in drive and loading from drive

# %%
import os 
from PIL import Image
def centre_crop(image):
    a , b = image.size
    main_edge = a if a < b else b
    ratio = main_edge/100
    new_a, new_b = int(a/ratio), int(b/ratio)
    crop_a, crop_b = (new_a - 100)//2 , (new_b-100)//2
    image = image.resize((new_a, new_b))
    image = image.crop((crop_a,crop_b,crop_a+100,crop_b+100))
    return image

# %%
for root in ('test_data', 'train_data'):
  for folder in os.listdir(root):
    for file in os.listdir(root+ '/' +folder):
        image = Image.open(root+ '/' +folder+ '/'+file)
        image = centre_crop(image)
        image.save(root+ '/' +folder+ '/'+file)

# %%
# !zip -r test_data100.zip test_data/ 
# !zip -r train_data100.zip train_data/

# %%
! cp train_data100.zip gdrive/My\ Drive/Colab\ Notebooks/Model\ type
! cp test_data100.zip gdrive/My\ Drive/Colab\ Notebooks/Model\ type

# %%
! cp gdrive/My\ Drive/Colab\ Notebooks/Model\ type/train_data100_new.zip .
! cp gdrive/My\ Drive/Colab\ Notebooks/Model\ type/test_data100.zip .

# %%
# !unzip test_data100.zip
# !unzip train_data100_new.zip

# %% [markdown]
# ## Creating Net class

# %%
import torch
torch.manual_seed(42)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.backends.cuda.cufft_plan_cache.max_size = 2048
torch.cuda.empty_cache()
from torch import nn, optim
import datetime
from torchvision import datasets, transforms, models
from PIL import Image
from collections import OrderedDict

# %%
class TempletLayer(nn.Module):

  def __init__(self, n_input, n_output, kernel, stride):
    super(TempletLayer, self).__init__()
    self.conv = nn.Conv2d(n_input, n_output, kernel_size=kernel, stride=stride, bias=False)
    self.bn =  nn.BatchNorm2d(n_output, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
    self.relu = nn.ReLU(inplace=True)
    #self.pool = nn.AvgPool2d(kernel_size=kernel, stride=stride,   ceil_mode=False) #dilation=1,
    
   
  def forward(self, x):
     x = self.conv(x)
     x = self.bn(x)
     x = self.relu(x)
     #x = self.pool(x)
     return x

# %%
class Net(nn.Module):
  
  def __init__(self):
    super(Net, self).__init__()
    self.features = nn.Sequential(
                    OrderedDict([('layer1', TempletLayer( n_input=3, n_output=1024, kernel=(5,5), stride=(2,2)) ),
                                 ('maxpool1' , nn.MaxPool2d(kernel_size=(3,3), stride=(1,1), dilation=1,  ceil_mode=False) ),
                                 ('layer2', TempletLayer( n_input=1024, n_output=512, kernel=(3,3), stride=(1,1)) ),
                                 ('maxpool2' , nn.MaxPool2d(kernel_size=(2,2), stride=(1,1), dilation=1,  ceil_mode=False) ),
                                 ('layer3', TempletLayer( n_input=512, n_output=256, kernel=(3,3), stride=(1,1)) ),
                                 ('maxpool3' , nn.MaxPool2d(kernel_size=(2,2), stride=(1,1), dilation=1,  ceil_mode=False) ),
                                 ('adtavgpool' , nn.AvgPool2d(kernel_size=(4,4), stride=(4,4), ceil_mode=False) ),
                                ]))
    self.adtpool = nn.AdaptiveMaxPool2d(output_size=(1, 1)) 
    self.classifier = nn.Sequential(
                        OrderedDict([ ('dropout1', nn.Dropout(p=0.3, inplace=False)), 
                                      ('fc1', nn.Linear(256, 5)),
                                      ('output', nn.LogSoftmax(dim=1))
                                      ]))                           
    self.criterion = nn.NLLLoss()
    self.transform = transforms.Compose([transforms.Lambda(self.centre_crop), 
                                            transforms.ToTensor(),
                                            transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))])
    self.train_transform = transforms.Compose([transforms.ToTensor(),
                                                  transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))])
    self.train_loss_hist = [] 
    self.val_loss_hist = []
    self.val_acc_hist = []

  def forward(self, x):
    x = self.features(x)
    x = self.adtpool(x)
    x = x.flatten(1) 
    x = self.classifier(x)
    return x

  @staticmethod
  def centre_crop(image):
    a , b = image.size
    main_edge = a if a < b else b
    ratio = main_edge/224
    new_a, new_b = int(a/ratio), int(b/ratio)
    crop_a, crop_b = int((new_a - 224)/2) , int((new_b-224)/2)
    image = image.resize((new_a, new_b))
    image = image.crop((crop_a,crop_b,crop_a+224,crop_b+224))
    return image
  
  
  def fit(self, trainloader, testloader, device, epochs=5, save_path='model.torch', optimizer = None):

    if optimizer is None:
      optimizer = optim.Adam(self.parameters(), lr=0.0005)
    
    self.to(device)

    for e in range(epochs):
      self.train()
      train_loss = 0.0

      estart = datetime.datetime.now()
      print('starting epoch ', e , ' at  ' , estart )
      
      for images, labels  in trainloader:
        images = images.to(device)
        labels = labels.to(device)
        optimizer.zero_grad()
        predicts = self(images)
        
        loss = self.criterion(predicts, labels)
        loss.backward()
        optimizer.step()       
        train_loss += float(loss)

        del images, labels, loss, predicts
                        
      else:
        train_loss = train_loss/ len(trainloader)
        print('train_loss = ', train_loss )
        print('End of epoch ', e , ' at  ' , datetime.datetime.now() , 'duration = ', datetime.datetime.now() - estart )
        self.evaluate(testloader=testloader, device=device, save_path=save_path, train_loss=train_loss, save = True ) 


  def evaluate(self, testloader, device, save_path, train_loss=0, save = False, initial_val_acc = None ):

    if initial_val_acc is None:
      try:
        initial_val_acc = max(self.val_acc_hist)
      except (IndexError, ValueError) as e:
          initial_val_acc = 0
    estart = datetime.datetime.now()
    print('Starting validation at ' , estart )
    self.to(device)
    self.eval()
    val_acc = 0.0
    val_loss = 0.0
    with torch.no_grad():
      for images, labels in testloader:
        images = images.to(device)
        labels = labels.to(device)
        predicts = self(images)

        loss = self.criterion(predicts, labels)
        val_loss += float(loss)

        predicts = torch.exp(predicts)
        top_p, top_class = predicts.topk(1, dim=1)
        equals = top_class == labels.view(*top_class.shape)
        val_acc+= float(torch.mean(equals.type(torch.FloatTensor)).item())

        del images, labels, loss, predicts, top_p, top_class, equals
          
    self.train()
    val_acc =  val_acc/ len(testloader)
    val_loss =  val_loss/ len(testloader)
    print('End of validation at ' , datetime.datetime.now() , 'duration = ', datetime.datetime.now() - estart )
    print('val_acc= ', val_acc,'val_loss=',val_loss)

    if save:
      self.train_loss_hist.append(train_loss)
      self.val_loss_hist.append(val_loss) 
      self.val_acc_hist.append(val_acc)  
      
      if val_acc >= initial_val_acc:
        print('saving model in ', save_path)
        torch.save(self, save_path)
    
    return val_acc, val_loss

# %% [markdown]
# ## Training The model

# %%
model_path = '/model_clasifier_v_3_0.torch'
#model = Net()
model = torch.load( root_dir + model_path)
model
# Out:
# Net(
#   (features): Sequential(
#     (layer1): TempletLayer(
#       (conv): Conv2d(3, 1024, kernel_size=(5, 5), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (maxpool1): MaxPool2d(kernel_size=(3, 3), stride=(1, 1), padding=0, dilation=1, ceil_mode=False)
#     (layer2): TempletLayer(
#       (conv): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (maxpool2): MaxPool2d(kernel_size=(2, 2), stride=(1, 1), padding=0, dilation=1, ceil_mode=False)
#     (layer3): TempletLayer(
#       (conv): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
# ...

# %%
train_data = datasets.ImageFolder('train_data', transform=model.train_transform)
test_data  = datasets.ImageFolder('test_data',  transform=model.train_transform)

train_loader = torch.utils.data.DataLoader(train_data, batch_size=64, shuffle=True, num_workers=4)
test_loader  = torch.utils.data.DataLoader(test_data,  batch_size=64, shuffle=True, num_workers=4)

# %%
model.fit(trainloader=train_loader, testloader=test_loader, device=device, epochs=100, save_path= root_dir + model_path)
#model.evaluate(test_loader, device, save_path = root_dir + model_path , train_loss=0, save = False, initial_val_acc = 0 )
# Out:
# starting epoch  0  at   2020-05-28 07:43:23.699137
# train_loss =  0.9384832829005958
# End of epoch  0  at   2020-05-28 08:05:06.187717 duration =  0:21:42.488595
# Starting validation at  2020-05-28 08:05:06.188825
# End of validation at  2020-05-28 08:05:24.211477 duration =  0:00:18.022664
# val_acc=  0.6244902483960415 val_loss= 1.0247814071939347
# starting epoch  1  at   2020-05-28 08:05:24.213592
# train_loss =  0.9202395239079646
# End of epoch  1  at   2020-05-28 08:27:09.501639 duration =  0:21:45.288060
# Starting validation at  2020-05-28 08:27:09.501938
# End of validation at  2020-05-28 08:27:27.467924 duration =  0:00:17.965999
# val_acc=  0.6261968080033647 val_loss= 1.0227186527658017
# starting epoch  2  at   2020-05-28 08:27:27.469905
# train_loss =  0.9026548573675082
# End of epoch  2  at   2020-05-28 08:49:10.107015 duration =  0:21:42.637123
# Starting validation at  2020-05-28 08:49:10.107381
# ...

# %%
from matplotlib import pyplot as plt
plt.scatter(range(len(model.train_loss_hist)),model.train_loss_hist )
plt.scatter(range(len(model.val_loss_hist)), model.val_loss_hist, c='r' )

# %% [markdown]
# ## Load and evaluate model

# %%
max(model.val_acc_hist)
# Out:
# 0.6109264188624443

# %%
m = models.alexnet()
m
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
# ...

# %%
model.eval()
accuracy = []
with torch.no_grad():
    for images, labels in testloader:
        images = images.to(device)
        labels = labels.to(device)
        ps = torch.exp(model(images))
        top_p, top_class = ps.topk(1, dim=1)
        equals = top_class == labels.view(*top_class.shape)
        accuracy.append(torch.mean(equals.type(torch.FloatTensor)).item())
mean_acc = torch.mean(torch.tensor(accuracy)).item()
print(mean_acc)
initial_val_acc = mean_acc
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-26-39b9a9b02cfb> in <module>()
#       5         images = images.to(device)
#       6         labels = labels.to(device)
# ----> 7         ps = torch.exp(model(images))
#       8         top_p, top_class = ps.topk(1, dim=1)
#       9         equals = top_class == labels.view(*top_class.shape)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# <ipython-input-5-537a8a2cd49a> in forward(self, x)
#      24
#      25     def forward(self, x):
# ---> 26         x = self.features(x)
# ...

# %% [markdown]
# ## Manual tests

# %%
! wget https://instagram.fevn5-1.fna.fbcdn.net/v/t51.2885-15/e35/95872355_3056415481084766_3165675729722034112_n.jpg?_nc_ht=instagram.fevn5-1.fna.fbcdn.net&_nc_cat=102&_nc_ohc=DVf_4J-K1CcAX_IqxKB&oh=245624c38acdf5e4ce9653b2d39a00b5&oe=5EE0AFCE
# Out:
# --2020-05-08 11:52:35--  https://instagram.fevn5-1.fna.fbcdn.net/v/t51.2885-15/e35/95872355_3056415481084766_3165675729722034112_n.jpg?_nc_ht=instagram.fevn5-1.fna.fbcdn.net
# Resolving instagram.fevn5-1.fna.fbcdn.net (instagram.fevn5-1.fna.fbcdn.net)... 217.76.4.97, 2a00:1f28:0:17:face:b00c:3333:a3f
# Connecting to instagram.fevn5-1.fna.fbcdn.net (instagram.fevn5-1.fna.fbcdn.net)|217.76.4.97|:443... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2020-05-08 11:52:36 ERROR 403: Forbidden.

# %%
from PIL import Image

# %%
image = Image.open( 'test_data/1plus/5.jpg')
image = model.train_transform(image).float()
image = image.unsqueeze(0)#.to(device)
image.shape
# Out:
# torch.Size([1, 3, 100, 100])

# %%
t = TempletLayer( n_input=3, n_output=128, kernel=(5,5), stride=(2,2))
t.eval()
with torch.no_grad():
    a = t(image) 
a.shape
# Out:
# torch.Size([1, 128, 48, 48])

# %%
av = nn.MaxPool2d(kernel_size=(3,3), stride=(1,1), dilation=1,  ceil_mode=False)
b = av(a)
b.shape
# Out:
# torch.Size([1, 128, 46, 46])

# %%
# Out:
# Net(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (STD_layers): STD_leyer(
#     (conv1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#     (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv4): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
model1 = STD_leyer()
model1
# Out:
# STD_leyer(
#   (conv1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(256, 256, kernel_size=(5, 5), stride=(1, 1), bias=False)
#   (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): Conv2d(256, 2048, kernel_size=(7, 7), stride=(1, 1), bias=False)
#   (bn4): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
# )

# %%
model1.eval()
with torch.no_grad():
    b = model1(a)

# %%
b.shape
# Out:
# torch.Size([1, 2048, 46, 46])

# %%
model.eval()
with torch.no_grad():
    a = model(image) 

for_map = { 0: 'Plus-Size Model',
    1: 'Fitness or Fit model',
    2: 'Swimsuit or Lingerie Model',
    4: 'Commercial Model',
    5: 'Glamour or Fashion Model' }
sorte, indices =  (torch.exp(a)*100).sort(descending=True) 

print( f"""{round(sorte[0][0].item())} % {for_map[indices[0][0].item()]}
{round(sorte[0][1].item())} % {for_map[indices[0][1].item()]}
{round(sorte[0][2].item())} % {for_map[indices[0][2].item()]} """ )
# Out:
# 96 % Necked beauty Model
# 2 % Swimsuit or Lingerie Model
# 1 % Commercial Model

# %%
sorte, indices =  torch.exp(a).sort(descending=True)

# %%
sorted[0][0]
# Out:
# tensor(0.5992, device='cuda:0')

# %%
indices[0][0]
# Out:
# tensor(4, device='cuda:0')

# %%
m = models.resnet18()

# %%
m
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...
